# %% [markdown]
# # **Neuroprocessors**

# %% [markdown]
# ## **Examples**

# %% [markdown]
# ### **Nvidia products**

# %% [markdown]
# ![Jetson.jpg](attachment:Jetson.jpg)

# %% [markdown]
# ### **Intel products**

# %% [markdown]
# ![NS2.jpeg](attachment:NS2.jpeg)

# %% [markdown]
# ### **Google products**

# %% [markdown]
# ![coral.jpg](attachment:coral.jpg)

# %% [markdown]
# ## **Interacting with NS2**

# %% [markdown]
# ### **Pulling env**

# %%
# !docker pull openvino/ubuntu20_dev:2022.1.0
# Out:
# 2022.1.0: Pulling from openvino/ubuntu20_dev
# Digest: sha256:3b16f830655f89639e5a99b172a2db5cbb67e1f9f6f1154423852e9985eb5f05
# Status: Image is up to date for openvino/ubuntu20_dev:2022.1.0
# docker.io/openvino/ubuntu20_dev:2022.1.0

# %% [markdown]
# You need to download resnet50 in onnx format,rename this file to `resnet50_opset11.onnx` and move it to `ov_ws` dir.

# %% [markdown]
# ### **Start container with NS2 inside your laptop**
